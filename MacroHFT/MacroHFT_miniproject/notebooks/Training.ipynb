# %%
! pip install --user torch pandas numpy matplotlib jupyter scipy tqdm scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch, pandas, numpy, matplotlib
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")  # Check GPU support
print("All libraries loaded successfully!")
# Out:
# PyTorch version: 2.6.0+cpu
# CUDA available: False
# All libraries loaded successfully!

# %%
# In your FIRST notebook cell:
import os

# Set the project root (adjust if needed)
PROJECT_ROOT = r"C:\Users\KIIT\OneDrive\Desktop\MacroHFT\MacroHFT_miniproject"
os.chdir(PROJECT_ROOT)  # Critical - sets working directory

# Verify paths
print("Current directory:", os.getcwd())
print("high_level.py exists:", os.path.exists("RL/agent/high_level.py"))
# Out:
# Current directory: C:\Users\KIIT\OneDrive\Desktop\MacroHFT\MacroHFT_miniproject
# high_level.py exists: True

# %%
# Magic command to run the entire file
# %run RL/agent/high_level.py
# Out:
# ...
# Starting training process...
# Current time: 2025-03-27 17:37:14
# ...
#
# Loading training data...
# Training data shape: (1000, 7)
# Validation data shape: (500, 7)
#
# Initializing environment...
#
# ...
# Initializing environment...
# Using indicators: ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'MACD', 'ATR']
# Environment initialized with 987 timesteps
# ...
#
# Initializing DQN agent with:
# • Input dim: 9 (features + position)
# • Output dim: 2 (actions)
# Agent initialized on cpu
#
# ...
# Beginning training...
# ...
#
#
# ...
# Initializing environment...
# Using indicators: ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'MACD', 'ATR']
# Environment initialized with 487 timesteps
# ...
#
# Saved new best model with return: 0.00
# Ep 001/20 | Train R: +nan | Val R: +0.00 | ε: 0.010 | Loss: 0.0000 | Q Error: 0.0000 | LR: 5.00e-04 | Ticker: Unknown
#
# ...
# Initializing environment...
# Using indicators: ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'MACD', 'ATR']
# Environment initialized with 487 timesteps
# ...
